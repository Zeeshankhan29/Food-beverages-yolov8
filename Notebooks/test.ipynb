# %%
import os 
default = {'data':45,'data1':901}
yaml = {'data':459,'data1':900}


updated_dict = {**default,**yaml}

from box import ConfigBox
updated_dict = ConfigBox(updated_dict)
updated_dict.data1
# Out:
# 900

# %%
for i,y in default.items():
    print(i,y)
# Out:
# data 45
# data1 901

# %%
default.items()
# Out:
# dict_items([('data', 45), ('data1', 901)])

# %%
[file for file in os.listdir(os.getcwd()) if file.endswith("yaml") ]
# Out:
# ['dvc.yaml', 'params.yaml']

# %%
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.github',
#  '.gitignore',
#  '.gitignore.save',
#  'artifacts',
#  'checkout.egg-info',
#  'configs',
#  'dvc.yaml',
#  'flask_server.py',
#  'init_setup.bat',
#  'init_setup.sh',
#  'log.txt',
#  'logs',
#  'main.py',
#  'models',
#  'Notebooks',
#  'params.yaml',
#  'prediction.py',
#  'prediction1.py',
#  'README-FILE.txt',
#  'README.md',
#  'requirements.txt',
#  'requirements_gpu.txt',
#  'requirements_linux.txt',
#  'setup.py',
#  'src',
#  'stage_01_data_ingestion.py',
#  'stage_02_data_transformation.py',
#  'stage_03_model_training.py',
#  'template.py',
#  'test.ipynb',
#  'yolo-config',
#  'yolov8m-seg.pt',
#  'yolov8n-seg.pt',
#  'yolov8n.pt',
#  'yolov8x-seg.pt']

# %%
d1 = {'data':45,'data1':90}
d2 = {'data':459,'data1':900}
 
for (data,value) , (data1,value1) in list(zip(d1.items(),d2.items())):
    print(data1,value1)
    print(data,value)
# Out:
# data 459
# data 45
# data1 900
# data1 90

# %%
meta = {**d1,**d2}
meta
# Out:
# {'data': 459, 'data1': 900}

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Zeeshan.khan\\vscode_projects\\self-checkout'

# %%
path = r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\mask'

# %%
path1 = r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\labels'

# %%
os.path.join(path1,'kiwi')
import shutil

# %%
for data in os.listdir(path):
    full_path = os.path.join(path,data)
    folder_name = os.path.basename(full_path)
    # print(folder_name,full_path)

    if folder_name in full_path:
        for files in os.listdir(full_path):
            file_dir = os.path.join(path1,folder_name)
            os.makedirs(file_dir,exist_ok=True)
            shutil.copy(full_path,file_dir)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[159], line 10
#       8 file_dir = os.path.join(path1,folder_name)
#       9 os.makedirs(file_dir,exist_ok=True)
# ---> 10 shutil.copy(full_path,file_dir)
#
# File c:\Users\Zeeshan.khan\AppData\Local\anaconda3\envs\self-checkout\lib\shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File c:\Users\Zeeshan.khan\AppData\Local\anaconda3\envs\self-checkout\lib\shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
# ...

# %%
import os
import shutil

# Iterate over files in the directory specified by 'path'
for data in os.listdir(path):
    full_path = os.path.join(path, data)  # Get the full path of the file
    if os.path.isdir(full_path):  # Check if the full path is a directory
        folder_name = os.path.basename(full_path)  # Get the folder name from the full path

        # Iterate over files in the subdirectory
        for file_name in os.listdir(full_path):
            file_path = os.path.join(full_path, file_name)  # Get the full path of the file

            file_dir = os.path.join(path1, folder_name)  # Create the destination directory path
            os.makedirs(file_dir, exist_ok=True)  # Create the destination directory if it doesn't exist

            shutil.copy(ile_dir)  # Copy the file to the destination directory

# %%
import os
import shutil
new_path =r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\labels'
new_path1 =r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\original'

# %%
text_files=[]
image_files=[]
for file in os.listdir(new_path):
    file_path = os.path.join(new_path,file)
    file_path1 = os.path.join(new_path1,file)
    for file_name in os.listdir(file_path):
        if file_name.endswith('.txt'):
            text_files.append(file_name)
    for file_name1 in os.listdir(file_path1):
        if file_name1.endswith('.png'):
            image_files.append(file_name1)
sorted_text_files = sorted(text_files)
sorted_image_files = sorted(image_files)
print(sorted_image_files)
print(sorted_text_files)

from sklearn.model_selection import train_test_split
text_train_data, text_test_data = train_test_split(sorted_text_files, test_size=0.2, random_state=42)
img_train_data, img_test_data = train_test_split(sorted_image_files, test_size=0.2, random_state=42)
# Copy the text files to the destination directory based on their classes
for files in text_train_data:
    for classes in os.listdir(new_path):
        file_name = os.path.join(new_path,classes)
        file_path  = os.path.join(file_name,files)
        if os.path.exists(file_path):
            final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\labels\train')
            shutil.copy(file_path, final_path)
for files in text_test_data:
    for classes in os.listdir(new_path):
        file_name = os.path.join(new_path,classes)
        file_path  = os.path.join(file_name,files)
        if os.path.exists(file_path):
            final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\labels\val')
            shutil.copy(file_path, final_path)
for files in img_train_data:
    for classes in os.listdir(new_path1):
        file_name2 = os.path.join(new_path1,classes)
        file_path2  = os.path.join(file_name2,files)
        if os.path.exists(file_path2):
            final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\images\train')
            shutil.copy(file_path2, final_path)

for files in img_test_data:
    for classes in os.listdir(new_path1):
        file_name2 = os.path.join(new_path1,classes)
        file_path2  = os.path.join(file_name2,files)
        if os.path.exists(file_path2):
            final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\images\val')
            shutil.copy(file_path2, final_path)
# Out:
# ['1358Musk Melon_10-19-2022-16-12-5437601_Focus_12.png', '1358Musk Melon_10-19-2022-16-12-5437601_Focus_48.png', '1359Musk Melon_10-19-2022-16-12-5671745_Focus_12.png', '1359Musk Melon_10-19-2022-16-12-5771745_Focus_30.png', '1360Musk Melon_10-19-2022-16-12-5884960_Focus_48.png', '1360Musk Melon_10-19-2022-16-12-5984960_Focus_30.png', '1361Musk Melon_10-19-2022-16-13-0031022_Focus_12.png', '1361Musk Melon_10-19-2022-16-13-0031022_Focus_48.png', '1361Musk Melon_10-19-2022-16-13-0131022_Focus_30.png', '1362Musk Melon_10-19-2022-16-13-0210106_Focus_12.png', '1362Musk Melon_10-19-2022-16-13-0210106_Focus_48.png', '1362Musk Melon_10-19-2022-16-13-0310106_Focus_30.png', '1363Musk Melon_10-19-2022-16-13-1033017_Focus_12.png', '1363Musk Melon_10-19-2022-16-13-1033017_Focus_30.png', '1363Musk Melon_10-19-2022-16-13-1033017_Focus_48.png', '1364Musk Melon_10-19-2022-16-13-1278298_Focus_12.png', '1364Musk Melon_10-19-2022-16-13-1278298_Focus_48.png', '1365Musk Melon_10-19-2022-16-13-1674232_Focu
# ...

# %%
for files in text_train_data:
    print(files)
    # copy_path = os.path.join(fr'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\labels\{file}',files)
    # final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\labels\train1')
    # shutil.copy(copy_path,final_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[177], line 4
#       2 copy_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\temp\labels\kiwi',file)
#       3 final_path = os.path.join(r'C:\Users\Zeeshan.khan\vscode_projects\self-checkout\artifacts\data\labels\train1')
# ----> 4 shutil.copy(copy_path,final_path)
#
# File c:\Users\Zeeshan.khan\AppData\Local\anaconda3\envs\self-checkout\lib\shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File c:\Users\Zeeshan.khan\AppData\Local\anaconda3\envs\self-checkout\lib\shutil.py:254, in copyfile(src, dst, follow_symlinks)
# ...

# %%
for file in img_train_data:
    print(file)
# Out:
# 244Kiwi Imported Green_10-31-2022-14-57-1174938_Focus_20.png
# 313Pineapple Queen_10-29-2022-14-53-4937418_Focus_38.png
# 199Kiwi Imported Green_10-31-2022-14-48-307730_Focus_20.png
# 256Kiwi Imported Green_10-31-2022-15-00-2936314_Focus_2.png
# 246Kiwi Imported Green_10-31-2022-14-57-2547682_Focus_2.png
# 377Pineapple Queen_10-29-2022-14-55-5194489_Focus_2 - Copy - Copy.png
# 193Kiwi Imported Green_10-31-2022-14-47-2297630_Focus_2.png
# 221Kiwi Imported Green_10-31-2022-14-52-4383624_Focus_38.png
# 197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_20.png
# 195Kiwi Imported Green_10-31-2022-14-47-3396982_Focus_38.png
# 254Kiwi Imported Green_10-31-2022-15-00-0340931_Focus_20.png
# 206Kiwi Imported Green_10-31-2022-14-49-3580385_Focus_38.png
# 197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_38.png
# 222Kiwi Imported Green_10-31-2022-14-52-495416_Focus_2.png
# 377Pineapple Queen_10-29-2022-14-55-5194489_Focus_20.png
# ...

# %%
from sklearn.model_selection import train_test_split
train_data_j, test_data_j = train_test_split(sort_j, test_size=0.2, random_state=42)
train_data_l, test_data_l = train_test_split(sort_l, test_size=0.2, random_state=42)

# %%
len(train_data_j)
# Out:
# 225

# %%
test_data_j
# Out:
# ['224Kiwi Imported Green_10-31-2022-14-53-0683243_Focus_38.png',
#  '224Kiwi Imported Green_10-31-2022-14-53-0783243_Focus_20.png',
#  '268Kiwi Imported Green_10-31-2022-15-03-5953939_Focus_20.png',
#  '236Kiwi Imported Green_10-31-2022-14-56-2249548_Focus_38.png',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_20 - Copy - Copy.png',
#  '366Pineapple Queen_10-29-2022-14-55-2828825_Focus_38.png',
#  '219Kiwi Imported Green_10-31-2022-14-52-1243886_Focus_20.png',
#  '195Kiwi Imported Green_10-31-2022-14-47-3396982_Focus_2.png',
#  '374Pineapple Queen_10-29-2022-14-55-4494113_Focus_20 - Copy - Copy.png',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_38.png',
#  '352Pineapple Queen_10-29-2022-14-55-0059421_Focus_20.png',
#  '379Pineapple Queen_10-29-2022-14-55-5543655_Focus_20.png',
#  '374Pineapple Queen_10-29-2022-14-55-4494113_Focus_2 - Copy - Copy.png',
#  '339Pineapple Queen_10-29-2022-14-54-3991658_Focus_38.png',
# ...

# %%
train_data_l
# Out:
# ['244Kiwi Imported Green_10-31-2022-14-57-1174938_Focus_20.txt',
#  '313Pineapple Queen_10-29-2022-14-53-4937418_Focus_38.txt',
#  '199Kiwi Imported Green_10-31-2022-14-48-307730_Focus_20.txt',
#  '256Kiwi Imported Green_10-31-2022-15-00-2936314_Focus_2.txt',
#  '246Kiwi Imported Green_10-31-2022-14-57-2547682_Focus_2.txt',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_2 - Copy - Copy.txt',
#  '193Kiwi Imported Green_10-31-2022-14-47-2297630_Focus_2.txt',
#  '221Kiwi Imported Green_10-31-2022-14-52-4383624_Focus_38.txt',
#  '197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_20.txt',
#  '195Kiwi Imported Green_10-31-2022-14-47-3396982_Focus_38.txt',
#  '254Kiwi Imported Green_10-31-2022-15-00-0340931_Focus_20.txt',
#  '206Kiwi Imported Green_10-31-2022-14-49-3580385_Focus_38.txt',
#  '197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_38.txt',
#  '222Kiwi Imported Green_10-31-2022-14-52-495416_Focus_2.txt',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_20.txt',
# ...

# %%
train_data_j
# Out:
# ['244Kiwi Imported Green_10-31-2022-14-57-1174938_Focus_20.png',
#  '313Pineapple Queen_10-29-2022-14-53-4937418_Focus_38.png',
#  '199Kiwi Imported Green_10-31-2022-14-48-307730_Focus_20.png',
#  '256Kiwi Imported Green_10-31-2022-15-00-2936314_Focus_2.png',
#  '246Kiwi Imported Green_10-31-2022-14-57-2547682_Focus_2.png',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_2 - Copy - Copy.png',
#  '193Kiwi Imported Green_10-31-2022-14-47-2297630_Focus_2.png',
#  '221Kiwi Imported Green_10-31-2022-14-52-4383624_Focus_38.png',
#  '197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_20.png',
#  '195Kiwi Imported Green_10-31-2022-14-47-3396982_Focus_38.png',
#  '254Kiwi Imported Green_10-31-2022-15-00-0340931_Focus_20.png',
#  '206Kiwi Imported Green_10-31-2022-14-49-3580385_Focus_38.png',
#  '197Kiwi Imported Green_10-31-2022-14-48-1544984_Focus_38.png',
#  '222Kiwi Imported Green_10-31-2022-14-52-495416_Focus_2.png',
#  '377Pineapple Queen_10-29-2022-14-55-5194489_Focus_20.png',
# ...

# %%
from sklearn.model_selection import train_test_split

my_list = ['item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'item7', 'item8', 'item9', 'item10']

train_data, test_data = train_test_split(my_list, test_size=0.2, random_state=42)

print("Training data:")
print(train_data)
print("\nTesting data:")
print(test_data)
# Out:
# Training data:
# ['item6', 'item1', 'item8', 'item3', 'item10', 'item5', 'item4', 'item7']
#
# Testing data:
# ['item9', 'item2']

# %%
import os

# %%
dir = r'C:\Users\Zeeshan.khan\vscode_projects\checkout\artifacts\data\images\train'

# %%
os.listdir(dir)
# Out:
# ['0Apple Fuji_10-22-2022-16-11-2510775_Focus_2.png',
#  '0Apple Fuji_10-22-2022-16-11-2510775_Focus_38.png',
#  '100Apple Fuji_10-22-2022-16-30-4189478_Focus_2.png',
#  '100Apple Fuji_10-22-2022-16-30-4189478_Focus_20.png',
#  '100Mosambi_10-20-2022-12-48-4730659_Focus_2.png',
#  '102Apple Fuji_10-22-2022-16-30-4641387_Focus_2.png',
#  '102Apple Fuji_10-22-2022-16-30-4641387_Focus_20.png',
#  '103Apple Fuji_10-22-2022-16-30-5023171_Focus_2.png',
#  '103Apple Fuji_10-22-2022-16-30-5023171_Focus_20.png',
#  '103Mosambi_10-20-2022-12-49-2496186_Focus_2.png',
#  '103Mosambi_10-20-2022-12-49-2496186_Focus_20.png',
#  '104Apple Fuji_10-22-2022-16-30-5767534_Focus_38.png',
#  '104Apple Fuji_10-22-2022-16-30-5867534_Focus_2.png',
#  '104Mosambi_10-20-2022-12-49-2629718_Focus_2.png',
#  '104Mosambi_10-20-2022-12-49-2629718_Focus_20.png',
#  '104Mosambi_10-20-2022-12-49-2629718_Focus_38.png',
#  '105Apple Fuji_10-22-2022-16-30-5959193_Focus_2.png',
# ...

# %%
label = r'C:\Users\Zeeshan.khan\vscode_projects\checkout\artifacts\data\labels\train'

# %%
os.listdir(label)
# Out:
# ['0Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt',
#  '0Apple Fuji_10-22-2022-16-11-2510775_Focus_38.txt',
#  '100Apple Fuji_10-22-2022-16-30-4189478_Focus_20.txt',
#  '100Apple Fuji_10-22-2022-16-30-4189478_Focus_38.txt',
#  '102Apple Fuji_10-22-2022-16-30-4641387_Focus_2.txt',
#  '103Apple Fuji_10-22-2022-16-30-5023171_Focus_2.txt',
#  '103Apple Fuji_10-22-2022-16-30-5023171_Focus_20.txt',
#  '104Apple Fuji_10-22-2022-16-30-5767534_Focus_38.txt',
#  '105Apple Fuji_10-22-2022-16-30-5959193_Focus_2.txt',
#  '105Apple Fuji_10-22-2022-16-30-5959193_Focus_38.txt',
#  '106Apple Fuji_10-22-2022-16-31-0338138_Focus_2.txt',
#  '106Apple Fuji_10-22-2022-16-31-0338138_Focus_38.txt',
#  '107Apple Fuji_10-22-2022-16-31-0580557_Focus_38.txt',
#  '108Apple Fuji_10-22-2022-16-31-1213234_Focus_2.txt',
#  '108Apple Fuji_10-22-2022-16-31-1213234_Focus_20.txt',
#  '109Apple Fuji_10-22-2022-16-31-1451999_Focus_2.txt',
#  '109Apple Fuji_10-22-2022-16-31-1451999_Focus_20.txt',
# ...

# %%
# !pip install natsort

# %%
from natsort import natsorted

# %%
import re

file_names = []
for file in os.listdir(dir):
    file_parts = file.strip().split('.')
    result = [re.sub(r'^\d+', '', string) for string in file_parts]
    file_names.append(result[0])

sorted_names = sorted(file_names)

for name in sorted_names:
    print(name)
# Out:
# Apple Fuji_10-22-2022-16-11-2510775_Focus_2
# Apple Fuji_10-22-2022-16-11-2510775_Focus_38
# Apple Fuji_10-22-2022-16-11-4614448_Focus_2
# Apple Fuji_10-22-2022-16-11-4614448_Focus_20
# Apple Fuji_10-22-2022-16-11-4614448_Focus_38
# Apple Fuji_10-22-2022-16-11-5719566_Focus_20
# Apple Fuji_10-22-2022-16-11-5719566_Focus_38
# Apple Fuji_10-22-2022-16-12-1242584_Focus_2
# Apple Fuji_10-22-2022-16-13-0420112_Focus_2
# Apple Fuji_10-22-2022-16-13-0420112_Focus_38
# Apple Fuji_10-22-2022-16-13-0840738_Focus_38
# Apple Fuji_10-22-2022-16-13-0940738_Focus_2
# Apple Fuji_10-22-2022-16-13-1354737_Focus_2
# Apple Fuji_10-22-2022-16-13-1710940_Focus_2
# Apple Fuji_10-22-2022-16-13-1911811_Focus_38
# Apple Fuji_10-22-2022-16-16-045745_Focus_2
# Apple Fuji_10-22-2022-16-16-045745_Focus_20
# Apple Fuji_10-22-2022-16-16-2025818_Focus_2
# Apple Fuji_10-22-2022-16-16-43873_Focus_38
# Apple Fuji_10-22-2022-16-16-4598094_Focus_2
# Apple Fuji_10-22-2022-16-16-4884473_Focus_2
# ...

# %%
import re
from path import Path

file_names = []
for file in os.listdir(label):
    file_parts = file.strip().split('.')
    result = [re.sub(r'^\d+', '', string) for string in file_parts]
    dir1 = Path(os.path.join(os.getcwd(),'artifacts\data\labels\train'))
    old_file_name = os.path.join(dir1,file)
    new_file_name1 = os.path.join(dir1,result[0]+'.txt')
    # print(file_name1)
    os.rename(old_file_name,new_file_name1)
    # print(file,result[0])
#     file_names.append(result[0])

# sorted_names = sorted(file_names)

# for name in sorted_names:
#     print(name)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[48], line 12
#      10     new_file_name1 = os.path.join(dir1,result[0]+'.txt')
#      11     # print(file_name1)
# ---> 12     os.rename(old_file_name,new_file_name1)
#      13     # print(file,result[0])
#      14 #     file_names.append(result[0])
#      15
#    (...)
#      18 # for name in sorted_names:
#      19 #     print(name)
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'c:\\Users\\Zeeshan.khan\\vscode_projects\\checkout\\artifacts\\data\\labels\train\\0Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt' -> 'c:\\Users\\Zeeshan.khan\\vscode_projects\\checkout\\artifacts\\data\\labels\train\\Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt'

# %%
# !pip install Path
# Out:
# ...
#   Using cached path-16.6.0-py3-none-any.whl (26 kB)
# ...

# %%
import re
import os
from pathlib import Path

label_dir = "artifacts/data/labels/train"

for file in os.listdir(label_dir):
    file_parts = file.strip().split('.')
    result = [re.sub(r'^\d+', '', string) for string in file_parts]

    old_file_path = os.path.join(label_dir, file)
    new_file_name = result[0] + '.txt'
    new_file_path = os.path.join(label_dir, new_file_name)

    if os.path.exists(old_file_path):
        os.rename(old_file_path, new_file_path)
        print(f"Renamed '{file}' to '{new_file_name}'")
    else:
        print(f"File '{file}' does not exist")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[84], line 16
#      13 new_file_path = os.path.join(label_dir, new_file_name)
#      15 if os.path.exists(old_file_path):
# ---> 16     os.rename(old_file_path, new_file_path)
#      17     print(f"Renamed '{file}' to '{new_file_name}'")
#      18 else:
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'artifacts/data/labels/train\\0Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt' -> 'artifacts/data/labels/train\\Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt'

# %%
import os
label_dir = "artifacts/data/labels/train"

file= os.listdir(label_dir)
sorted(file)
# Out:
# ['Apple Fuji_10-22-2022-16-11-2510775_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-11-2510775_Focus_38.txt',
#  'Apple Fuji_10-22-2022-16-11-4614448_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-11-4614448_Focus_20.txt',
#  'Apple Fuji_10-22-2022-16-11-4614448_Focus_38.txt',
#  'Apple Fuji_10-22-2022-16-11-5719566_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-11-5719566_Focus_20.txt',
#  'Apple Fuji_10-22-2022-16-11-5719566_Focus_38.txt',
#  'Apple Fuji_10-22-2022-16-12-1242584_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-12-1448501_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-12-1548501_Focus_20.txt',
#  'Apple Fuji_10-22-2022-16-13-0420112_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-13-0420112_Focus_38.txt',
#  'Apple Fuji_10-22-2022-16-13-0840738_Focus_38.txt',
#  'Apple Fuji_10-22-2022-16-13-0940738_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-13-1354737_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-13-1710940_Focus_2.txt',
#  'Apple Fuji_10-22-2022-16-13-1710940_Focus_38.txt',
# ...

# %%
a = [
      "Anjeer",
      "Apple Granny Smith",
      "Apple Pink Lady",
      "Apple Royal Gala",
      "Apple Shimla",
      "Apple Small",
      "Apricots Fresh Packed",
      "Ash Gourd Cut",
      "Avocado Indian",
      "Banana Flower",
      "Banana Hills",
      "Banana Morris",
      "Banana Nendran",
      "Banana Poovan",
      "Banana Rasthali",
      "Banana Red",
      "Beetroot",
      "Bere Elandai",
      "Bitter Gourd",
      "Bok Choy",
      "Bottle Gourd",
      "Brinjal Black Big",
      "Brinjal Long",
      "Brinjal Purple Striped",
      "Broccoli",
      "Cabbage",
      "Cabbage Red",
      "Capsicum",
      "Capsicum Red",
      "Capsicum Yellow",
      "Carrot Ooty",
      "Cassave",
      "Cauliflower",
      "Chilli Long Bajji",
      "Chinese Cabbage",
      "Coconut",
      "Coconut Flower",
      "Cucumber",
      "Custard Apple",
      "Dragon Fruit Red",
      "Golden Kiwi",
      "Gooseberry Amla",
      "Guava White",
      "Jackfruit raw",
      "Kale Leaves",
      "Karunai Kilangu",
      "Kiwi Green",
      "Knol Khol",
      "Lemon",
      "Lettuce Leaves",
      "Mango Neelam",
      "Mango Totapuri",
      "Mangusteens Indian",
      "Mosambi",
      "Muskmelon Rock",
      "Muskmelon Yellow",
      "Nectarines",
      "Onion Big Bellary",
      "Orange Nagpur",
      "Orange Small",
      "Orange Valencia",
      "Papaya",
      "Passion Fruit",
      "Pineapple",
      "Plums Imported",
      "Plums Indian",
      "Plums Indian Packed",
      "Pomegranate Kabul",
      "Potato Small Bag",
      "Pumpkin",
      "Pumpkin cut Wrapped",
      "Radish Red",
      "Radish White",
      "Sapota Round",
      "Snake Gourd",
      "Tomato Apple",
      "Tomato Nadu",
      "Turnip",
      "Watermelon Kiran",
      "Zucchini Green",
      "Zucchini Yellow"
]

# %%
b = ['Apple Granny Smith',
'Apple Royal Gala', 
'Apple Shimla',
'Ash Gourd Cut',
'Avocado Indian',
'Banana Flower', 
'Banana Hills', 
'Banana Nendran', 
'Banana Poovan', 
'Banana Rasthali', 
'Banana Red', 
'Bottle Gourd', 
'Brinjal Black Big', 
'Brinjal Purple Striped',
'Broccoli',
'Cabbage Red', 
'Cabbage_', 
'Capsicum Red', 
'Capsicum Yellow', 
'Capsicum_', 
'Cauliflower', 
'Cucumber', 
'Dragon Fruit Red',
'Golden Kiwi', 
'Gooseberry Amla', 
'Guava White', 
'Jackfruit Raw', 
'Kiwi Green', 
'Lemon', 
'Mango Neelam', 
'Mango Totapuri', 
'Mangusteens Indian', 
'Mosambi', 
'Muskmelon Rock', 
'Muskmelon Yellow', 
'Nectarines', 
'Onion Big Bellary', 
'Orange Valencia', 
'Papaya', 
'Pineapple', 
'Pomegranate Kabul', 
'Pumpkin Cut Wrapped', 
'Radish Red', 
'Radish White', 
'Sapota Round', 
'Tomato Apple', 
'Tomato Nadu', 
'Turnip', 
'Watermelon Kiran', 
'Zucchini Green', 
'Zucchini Yellow']

# %%
a = set(a)
b = set(b)
from IPython.display import display
c = a.difference(b)

c
# Out:
# {'Anjeer',
#  'Apple Pink Lady',
#  'Apple Small',
#  'Apricots Fresh Packed',
#  'Banana Morris',
#  'Beetroot',
#  'Bere Elandai',
#  'Bitter Gourd',
#  'Bok Choy',
#  'Brinjal Long',
#  'Cabbage',
#  'Capsicum',
#  'Carrot Ooty',
#  'Cassave',
#  'Chilli Long Bajji',
#  'Chinese Cabbage',
#  'Coconut',
#  'Coconut Flower',
#  'Custard Apple',
#  'Jackfruit raw',
#  'Kale Leaves',
#  'Karunai Kilangu',
#  'Knol Khol',
#  'Lettuce Leaves',
#  'Orange Nagpur',
#  'Orange Small',
#  'Passion Fruit',
#  'Plums Imported',
#  'Plums Indian',
#  'Plums Indian Packed',
#  'Potato Small Bag',
#  'Pumpkin',
#  'Pumpkin cut Wrapped',
#  'Snake Gourd'}
